# %%
# %tensorflow_version 2.x
import tensorflow
tensorflow.__version__
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# '2.8.2'

# %%
import random
random.seed(0)

import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np

# %%
x=np.array([1,2,3,4,5,6,7,8])
y=np.array([9,10,11,12,13,14,16,17])

# %%
print(x)
# Out:
# [1 2 3 4 5 6 7 8]

# %%
np.mean(x)
# Out:
# 4.5

# %%
print(y)
# Out:
# [ 9 10 11 12 13 14 16 17]

# %%
np.mean(y)
# Out:
# 12.75

# %%
type(x)
# Out:
# numpy.ndarray

# %%
#length of the dependent varaible:
len(y)
# Out:
# 8

# %%
#length of the Independent varaible:
len(x)
# Out:
# 8

# %%
#Definding the structure for our Neural Networks:

model=tensorflow.keras.models.Sequential([tensorflow.keras.layers.Flatten(),tensorflow.keras.layers.Dense(1)])

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 259ms/step - loss: 37.6716
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 17.2551
# Epoch 3/500
# 1/1 [==============================] - 0s 6ms/step - loss: 12.5986
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 11.4834
# Epoch 5/500
# 1/1 [==============================] - 0s 6ms/step - loss: 11.1644
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 11.0248
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 10.9261
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 10.8371
# Epoch 9/500
# 1/1 [==============================] - 0s 13ms/step - loss: 10.7508
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 10.6656
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 10.5812
# Epoch 12/500
# ...
